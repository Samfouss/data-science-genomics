# %%
from final_project import read_fasta_file_and_process

# %%
res = read_fasta_file_and_process(filename="dna2.fasta", n_seq=7)

# %%
print(max(res["all_repeat_seq"].values()))
r = [k for k, v in res["all_repeat_seq"].items() if v == max(res["all_repeat_seq"].values())]
# Out:
# 12

# %%
print(r)
# Out:
# ['GCGGCCG']

# %%
res["stat"]["max_repeat_seq"]
# Out:
# 2

# %%
print(min(res["stat"].values()))
# Out:
# 115
